# %% [markdown]
# <a href="https://colab.research.google.com/github/AnubhavMittra/tensorflow-simple-projects/blob/fashion-mnist/classification/fashion_mnist_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Install Libraries**

# %%
# !pip install tensorflow-gpu # Needed if notebook is run in local using GPU

# %% [markdown]
# # **Import Libraries**

# %%
import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU')

print("GPU:", tf.config.list_physical_devices('GPU'))
print("Num GPUs:", len(physical_devices))
print("Tensorflow version: ", tf.__version__)
# Out:
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Num GPUs: 1
# Tensorflow version:  2.12.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random

# %% [markdown]
# # **Load Dataset**

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %% [markdown]
# # **Data Visualization**

# %%
print("Training data size and shape: ", x_train.shape)
print("Test data size and shape: ", x_test.shape)
print("Training label size and shape: ", y_train.shape)
print("Test label size and shape: ", y_test.shape)
# Out:
# Training data size and shape:  (60000, 28, 28)
# Test data size and shape:  (10000, 28, 28)
# Training label size and shape:  (60000,)
# Test label size and shape:  (10000,)

# %%
plt.imshow(x_train[3])

# %%
y_train[3]
# Out:
# 3

# %%
num_rows = 3
num_cols = 4
num_images = num_rows * num_cols

labels = {
  0: "T-shirt/top",
  1: "Trouser",
  2: "Pullover",
  3: "Dress",
  4: "Coat",
  5: "Sandal",
  6: "Shirt",
  7: "Sneaker",
  8: "Bag",
  9: "Ankle boot"
}

# Create the grid view of images with labels
fig, axes = plt.subplots(num_rows, num_cols, figsize=(6, 4))

for i, ax in enumerate(axes.flat):
    # Generate a random image
    random_index = random.randint(1, x_train.shape[0])
    image = x_train[random_index]

    # Display the image and label
    ax.imshow(image, cmap='gray')
    ax.set_title(labels[y_train[random_index]]+" ("+str(y_train[random_index])+")")
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
# Create a grid view of 5 images for each category
fig, axes = plt.subplots(10, 5, figsize=(10, 15))

for category in range(10):
    category_images = x_train[y_train == category][:5]

    for i, ax in enumerate(axes[category]):
      ax.set_ylabel(labels[category])
      ax.imshow(category_images[i], cmap='gray', )

plt.tight_layout()
plt.show()
